# %% [markdown]
# # What is a Database?
# A `database` is a collection of data (information) stored electronically in a structured manner. The way the data is organized determines the type of database.
#
# ## Types of Database
#
# ### Hierarchical Databases
# Just as in any hierarchy, this database categorizes data in ranks or levels, and the ranks are expressed using links. It is organized in a parent-child relationship, and the entire database would resemble a tree.
#
# </br></br><img src="https://i.imgur.com/23nTU9D.png" width="1000"></br></br>
#
# #### Components of a Hierarchical Database
# A `hierarchical` database consists of a collection of records connected to each other through links. Each record is a collection of fields or attributes, each of which contains only one data value. A child record can only be linked to only one parent record.
#
# `record`[`fields/attributes`] <-- (`link`) --> `record`[`fields/attributes`]
#
# ### Network Databases
# A `network` database is a hierarchical database except that the child records can be associated with multiple parent records.
#
# </br></br><img src="https://i.imgur.com/MhP6vhP.png" width="1000"></br></br>
#
# ### Relational Databases
# `Relational` databases are the most mature of all databases. Every record can be linked to every other piece of record.
#
# #### Components of a Relational Database
# - Attributes
# - Entity
# - Relationships
# - Cardinality
#
# ### NoSQL Databases
# A `NoSQL` is a non-relational database that provides a mechanism for the storage and retrieval of data. A NoSQL database includes simplicity of design, simpler horizontal scaling to clusters of machines, and finer control over availability. The data structures used by NoSQL databases are very different from tables in relational databases, which makes some operations faster in NoSQL.
#
# ## Database Management Systems
# A `Database Management System` is a computerized data-keeping system. Users of the system are given facilities to perform several kinds of operations to either manipulate the data or manage the database structure itself. They are categorized according to their database structure or type: hierarchical, network, and relational.

# %% [markdown]
# # Relational Databases
# A database stores data in an organized way so that it can be searched and retrieved later. The database is made up of one or more tables. All rows have the same columns, and each column contains the data. Data can be inserted (created), retried, updated, and deleted from a table--CRUD abbreviated.
#
# A relational database is a type of database that organizes data into tables and creates links between these tables, based on defined relationships. These relationships enables the user to retrieve and combine data from one or more tables with a single query.

# %% [markdown]
# Below, we'll be using Foursquare API to build a database of bars and venues that accommodates live bands in Toronto and the GTA.

# %%
from dotenv import load_dotenv

import requests
import os
import pandas as pd

# %%
load_dotenv(override=True)
FSQ_API_KEY = os.environ["FOURSQUARE_API_KEY"]

# %% [markdown]
# To understand how to search the FSQ API for certain types of venues, we must first understand the taxonomy of their categories. FSQ Places includes a hierarchical taxonomy of categories from which each POI record is classified. The 10 parent categories are:
# - 10xxx Arts and Entertainment
# - 11xxx Business and Professional Services
# - 12xxx Community and Government
# - 13xxx Dining and Drinking
# - 14xxx Event
# - 15xxx Health and Medicine
# - 16xxx Landmarks and Outdoors
# - 17xxx Retail
# - 18xxx Sports and Recreation
# - 19xxx Travel and Transportation
#
# Each category is ID'd numerically as `10xxx` to `19xxx` in alphabetical order. Each subcategory is then organized numerically with the 3 remaining digits, `xxx`. Because we're looking for venues for live bands, we'll trim our options down to the following parent categories:
# - 100xx Arts and Entertainment
# - 13xxx Dining and Drinking
# - 14xxx Event

# %% [markdown]
# Use pandas to import category list and convert to Dataframe to manipulate into usable format.

# %%
df = pd.read_csv("./_data/places-and-apiv3-categories.csv", index_col=0)

# %%
df_split = df["Category Label"].str.split(' > ', expand=True)
df_split.head(5)
# Out:
#                             0               1     2     3     4     5
# 10000  Arts and Entertainment            None  None  None  None  None
# 10001  Arts and Entertainment  Amusement Park  None  None  None  None
# 10002  Arts and Entertainment        Aquarium  None  None  None  None
# 10003  Arts and Entertainment          Arcade  None  None  None  None
# 10004  Arts and Entertainment     Art Gallery  None  None  None  None

# %%
query = ""
results = df_split[df_split[1] == query.capitalize()]
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      object
#  1   1       0 non-null      object
#  2   2       0 non-null      object
#  3   3       0 non-null      object
#  4   4       0 non-null      object
#  5   5       0 non-null      object
# dtypes: object(6)
# memory usage: 0.0+ bytes

# %%
url = "https://api.foursquare.com/v3/places/search"
headers = {
  "accept" : "application/json",
  "Authorization" : FSQ_API_KEY
}

params = {
  "query" : "music",
  "near" : "Toronto"
}

response = requests.get(url, params=params, headers=headers)

# %%
response.json()
# Out:
# {'results': [{'fsq_id': '4b31677bf964a520530625e3',
#    'categories': [{'id': 12054,
#      'name': 'Music School',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_music_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 3890,
#    'geocodes': {'main': {'latitude': 43.668027, 'longitude': -79.396069},
#     'roof': {'latitude': 43.668027, 'longitude': -79.396069}},
#    'link': '/v3/places/4b31677bf964a520530625e3',
#    'location': {'address': '273 Bloor St W',
#     'country': 'CA',
#     'formatted_address': '273 Bloor St W, Toronto ON M5S 1W2',
#     'locality': 'Toronto',
#     'postcode': 'M5S 1W2',
#     'region': 'ON'},
#    'name': 'Royal Conservatory of Music',
#    'related_places': {'children': [{'fsq_id': '4adf787cf964a520e57a21e3',
#       'name': 'Koerner Hall'},
#      {'fsq_id': '4ba79edaf964a52020a339e3', 'name': 'B Expresso Bar'}]},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4ad4c062f964a520c1f720e3',
#    'categories': [{'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 7863,
#    'geocodes': {'main': {'latitude': 43.629264, 'longitude': -79.41503},
#     'roof': {'latitude': 43.629264, 'longitude': -79.41503}},
#    'link': '/v3/places/4ad4c062f964a520c1f720e3',
#    'location': {'address': '909 Lake Shore Blvd W',
#     'country': 'CA',
#     'cross_street': 'at Ontario Place',
#     'formatted_address': '909 Lake Shore Blvd W (at Ontario Place), Toronto ON M6K 3L3',
#     'locality': 'Toronto',
#     'postcode': 'M6K 3L3',
#     'region': 'ON'},
#    'name': 'Budweiser Stage',
#    'related_places': {'parent': {'fsq_id': '4c10206ae7d295216fbcd7b0',
#      'name': 'Ontario Place'},
#     'children': [{'fsq_id': '4c4a2ea1712ac928b9d2116b',
#       'name': 'American Express Lounge'},
#      {'fsq_id': '5d0d4159733dc40023c175de', 'name': 'Skyline Lounge'}]},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4af5d9a9f964a520cafd21e3',
#    'categories': [{'id': 17098,
#      'name': 'Music Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/music_instruments_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 4377,
#    'geocodes': {'main': {'latitude': 43.661443, 'longitude': -79.427143},
#     'roof': {'latitude': 43.661443, 'longitude': -79.427143}},
#    'link': '/v3/places/4af5d9a9f964a520cafd21e3',
#    'location': {'address': '925 Bloor St W',
#     'country': 'CA',
#     'cross_street': 'at Concord Ave.',
#     'formatted_address': '925 Bloor St W (at Concord Ave.), Toronto ON M6H 1L5',
#     'locality': 'Toronto',
#     'postcode': 'M6H 1L5',
#     'region': 'ON'},
#    'name': 'Long and McQuade',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4ad4c062f964a520f2f720e3',
#    'categories': [{'id': 10037,
#      'name': 'Concert Hall',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}},
#     {'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}},
#     {'id': 10043,
#      'name': 'Theater',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 5443,
#    'geocodes': {'main': {'latitude': 43.676479, 'longitude': -79.35691},
#     'roof': {'latitude': 43.676479, 'longitude': -79.35691}},
#    'link': '/v3/places/4ad4c062f964a520f2f720e3',
#    'location': {'address': '147 Danforth Ave',
#     'country': 'CA',
#     'cross_street': 'at Broadview Ave.',
#     'formatted_address': '147 Danforth Ave (at Broadview Ave.), Toronto ON M4K 1N2',
#     'locality': 'Toronto',
#     'postcode': 'M4K 1N2',
#     'region': 'ON'},
#    'name': 'The Music Hall',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4de94b3cd4c0faa56445dbee',
#    'categories': [{'id': 10037,
#      'name': 'Concert Hall',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}},
#     {'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 7859,
#    'geocodes': {'main': {'latitude': 43.629147, 'longitude': -79.415104},
#     'roof': {'latitude': 43.629147, 'longitude': -79.415104}},
#    'link': '/v3/places/4de94b3cd4c0faa56445dbee',
#    'location': {'address': '909 Lake Shore Blvd W',
#     'country': 'CA',
#     'cross_street': 'Ontario Place',
#     'formatted_address': '909 Lake Shore Blvd W (Ontario Place), Toronto ON M6K 3L3',
#     'locality': 'Toronto',
#     'postcode': 'M6K 3L3',
#     'region': 'ON'},
#    'name': 'TD Echo Beach',
#    'related_places': {'children': []},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '514cc159e4b0e4f73af4eced',
#    'categories': [{'id': 10040,
#      'name': 'Jazz and Blues Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13135,
#      'name': 'Cuban Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cuban_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 5764,
#    'geocodes': {'main': {'latitude': 43.655781, 'longitude': -79.379155},
#     'roof': {'latitude': 43.655781, 'longitude': -79.379155}},
#    'link': '/v3/places/514cc159e4b0e4f73af4eced',
#    'location': {'address': '251 Victoria St',
#     'country': 'CA',
#     'cross_street': 'btwn Dundas St. E & Shuter St.',
#     'formatted_address': '251 Victoria St (btwn Dundas St. E & Shuter St.), Toronto ON M5B 1T8',
#     'locality': 'Toronto',
#     'postcode': 'M5B 1T8',
#     'region': 'ON'},
#    'name': 'Jazz Bistro',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4baa0f32f964a5205b473ae3',
#    'categories': [{'id': 16017,
#      'name': 'Garden',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#       'suffix': '.png'}},
#     {'id': 18000,
#      'name': 'Sports and Recreation',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 7250,
#    'geocodes': {'main': {'latitude': 43.637096, 'longitude': -79.39455}},
#    'link': '/v3/places/4baa0f32f964a5205b473ae3',
#    'location': {'address': '475 Queens Quay W',
#     'country': 'CA',
#     'cross_street': 'Spadina',
#     'formatted_address': '475 Queens Quay W (Spadina), Toronto ON',
#     'locality': 'Toronto',
#     'region': 'ON'},
#    'name': 'Toronto Music Garden',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4ad4c05df964a52067f620e3',
#    'categories': [{'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}},
#     {'id': 13009,
#      'name': 'Cocktail Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 5615,
#    'geocodes': {'drop_off': {'latitude': 43.649612, 'longitude': -79.420848},
#     'main': {'latitude': 43.649676, 'longitude': -79.420677},
#     'roof': {'latitude': 43.649676, 'longitude': -79.420677}},
#    'link': '/v3/places/4ad4c05df964a52067f620e3',
#    'location': {'address': '249 Ossington Ave',
#     'country': 'CA',
#     'cross_street': 'at Dundas St.',
#     'formatted_address': '249 Ossington Ave (at Dundas St.), Toronto ON M6J 3A1',
#     'locality': 'Toronto',
#     'postcode': 'M6J 3A1',
#     'region': 'ON'},
#    'name': 'The Dakota Tavern',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b522e7df964a520ec6d27e3',
#    'categories': [{'id': 17098,
#      'name': 'Music Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/music_instruments_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 10822,
#    'geocodes': {'main': {'latitude': 43.781526, 'longitude': -79.490488},
#     'roof': {'latitude': 43.781526, 'longitude': -79.490488}},
#    'link': '/v3/places/4b522e7df964a520ec6d27e3',
#    'location': {'address': '2777 Steeles Ave W',
#     'address_extended': '# 10',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '2777 Steeles Ave W, North York ON M3J 3K5',
#     'locality': 'North York',
#     'postcode': 'M3J 3K5',
#     'region': 'ON'},
#    'name': 'Long and McQuade',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '551128d4498e2e50d8f03c5b',
#    'categories': [{'id': 11167,
#      'name': 'Technology Business',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 7240,
#    'geocodes': {'main': {'latitude': 43.650115, 'longitude': -79.358947},
#     'roof': {'latitude': 43.650115, 'longitude': -79.358947}},
#    'link': '/v3/places/551128d4498e2e50d8f03c5b',
#    'location': {'address': '179 John St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '179 John St, Toronto ON M5T 1X4',
#     'locality': 'Toronto',
#     'postcode': 'M5T 1X4',
#     'region': 'ON'},
#    'name': 'Spotify',
#    'related_places': {},
#    'timezone': 'America/Toronto'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.70011,
#      'longitude': -79.4163},
#     'radius': 16290}}}}

# %%
df = pd.DataFrame(response.json()['results'])

# %%
df
# Out:
#                      fsq_id  \
# 0  4b31677bf964a520530625e3
# 1  4ad4c062f964a520c1f720e3
# 2  4af5d9a9f964a520cafd21e3
# 3  4ad4c062f964a520f2f720e3
# 4  4de94b3cd4c0faa56445dbee
# 5  514cc159e4b0e4f73af4eced
# 6  4baa0f32f964a5205b473ae3
# 7  4ad4c05df964a52067f620e3
# 8  4b522e7df964a520ec6d27e3
# 9  551128d4498e2e50d8f03c5b
#
#                                           categories chains  distance  \
# 0  [{'id': 12054, 'name': 'Music School', 'icon':...     []      3890
# 1  [{'id': 10039, 'name': 'Music Venue', 'icon': ...     []      7863
# 2  [{'id': 17098, 'name': 'Music Store', 'icon': ...     []      4377
# 3  [{'id': 10037, 'name': 'Concert Hall', 'icon':...     []      5443
# 4  [{'id': 10037, 'name': 'Concert Hall', 'icon':...     []      7859
# 5  [{'id': 10040, 'name': 'Jazz and Blues Venue',...     []      5764
# 6  [{'id': 16017, 'name': 'Garden', 'icon': {'pre...     []      7250
# 7  [{'id': 10039, 'name': 'Music Venue', 'icon': ...     []      5615
# 8  [{'id': 17098, 'name': 'Music Store', 'icon': ...     []     10822
# 9  [{'id': 11167, 'name': 'Technology Business', ...     []      7240
#
#                                             geocodes  \
# 0  {'main': {'latitude': 43.668027, 'longitude': ...
# 1  {'main': {'latitude': 43.629264, 'longitude': ...
# 2  {'main': {'latitude': 43.661443, 'longitude': ...
# 3  {'main': {'latitude': 43.676479, 'longitude': ...
# 4  {'main': {'latitude': 43.629147, 'longitude': ...
# 5  {'main': {'latitude': 43.655781, 'longitude': ...
# 6  {'main': {'latitude': 43.637096, 'longitude': ...
# 7  {'drop_off': {'latitude': 43.649612, 'longitud...
# 8  {'main': {'latitude': 43.781526, 'longitude': ...
# 9  {'main': {'latitude': 43.650115, 'longitude': ...
#
#                                   link  \
# 0  /v3/places/4b31677bf964a520530625e3
# 1  /v3/places/4ad4c062f964a520c1f720e3
# 2  /v3/places/4af5d9a9f964a520cafd21e3
# 3  /v3/places/4ad4c062f964a520f2f720e3
# 4  /v3/places/4de94b3cd4c0faa56445dbee
# 5  /v3/places/514cc159e4b0e4f73af4eced
# 6  /v3/places/4baa0f32f964a5205b473ae3
# 7  /v3/places/4ad4c05df964a52067f620e3
# 8  /v3/places/4b522e7df964a520ec6d27e3
# 9  /v3/places/551128d4498e2e50d8f03c5b
#
#                                             location  \
# 0  {'address': '273 Bloor St W', 'country': 'CA',...
# 1  {'address': '909 Lake Shore Blvd W', 'country'...
# 2  {'address': '925 Bloor St W', 'country': 'CA',...
# 3  {'address': '147 Danforth Ave', 'country': 'CA...
# 4  {'address': '909 Lake Shore Blvd W', 'country'...
# 5  {'address': '251 Victoria St', 'country': 'CA'...
# 6  {'address': '475 Queens Quay W', 'country': 'C...
# 7  {'address': '249 Ossington Ave', 'country': 'C...
# 8  {'address': '2777 Steeles Ave W', 'address_ext...
# 9  {'address': '179 John St', 'country': 'CA', 'c...
#
#                           name  \
# 0  Royal Conservatory of Music
# 1              Budweiser Stage
# 2             Long and McQuade
# 3               The Music Hall
# 4                TD Echo Beach
# 5                  Jazz Bistro
# 6         Toronto Music Garden
# 7            The Dakota Tavern
# 8             Long and McQuade
# 9                      Spotify
#
#                                       related_places         timezone
# 0  {'children': [{'fsq_id': '4adf787cf964a520e57a...  America/Toronto
# 1  {'parent': {'fsq_id': '4c10206ae7d295216fbcd7b...  America/Toronto
# 2                                                 {}  America/Toronto
# 3                                                 {}  America/Toronto
# 4                                   {'children': []}  America/Toronto
# 5                                                 {}  America/Toronto
# 6                                                 {}  America/Toronto
# 7                                                 {}  America/Toronto
# 8                                                 {}  America/Toronto
# 9                                                 {}  America/Toronto

# %%
df_categories = pd.DataFrame(category[0] for category in df['categories'])
df_categories
# Out:
#       id                  name  \
# 0  12054          Music School
# 1  10039           Music Venue
# 2  17098           Music Store
# 3  10037          Concert Hall
# 4  10037          Concert Hall
# 5  10040  Jazz and Blues Venue
# 6  16017                Garden
# 7  10039           Music Venue
# 8  17098           Music Store
# 9  11167   Technology Business
#
#                                                 icon
# 0  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 1  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 2  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 3  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 4  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 5  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 6  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 7  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 8  {'prefix': 'https://ss3.4sqi.net/img/categorie...
# 9  {'prefix': 'https://ss3.4sqi.net/img/categorie...

# %%
df_categories['icon'][0]
# Out:
# {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_music_',
#  'suffix': '.png'}

# %% [markdown]
# ## Entity Relationship Diagrams
#
# A common practice for visualizing relational data is through **Entity Relationship Diagrams** (ERD).
#
# An ERD can be used to understand, explore, and document a database. It can also help troubleshoot logic or deployment problems, spot inefficiencies, and help improve processes. For designing and modeling new databases, ERDs are indispensible.
#
# ### Best Practices
# - `Identify the Entities`: Identify all of the entities. An entity is nothing more than a description of a particular object that the system stores information about. Compartmentalize as best as possible.
# - `Identify the Relationship`: Reflect on how the two entities are related. Draw a solid line and label the line with a brief of description of relation.
# - `Add the Attributes`: Any key attributes of entities should be added using oval symbols.
# - `Complete the Diagram`: Continue to connect the entities with lines and add diamonds to describe each relationship until all relationships have been described. Use crow-foot's notation to complete the definitions.
